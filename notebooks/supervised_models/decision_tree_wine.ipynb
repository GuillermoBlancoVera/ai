# %% [markdown]
# # Decision Tree Classification on Wine
#
# Decision trees learn readable rules from data. This notebook trains a shallow tree, evaluates it, and inspects the most important features.

# %% [markdown]
# ## Imports and data

# %%
import pandas as pd
from sklearn.datasets import load_wine
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

wine = load_wine(as_frame=True)
x = wine.data
y = wine.target

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)

x.head()

# %% [markdown]
# ## Train and evaluate

# %%
model = DecisionTreeClassifier(max_depth=4, random_state=42)
model.fit(x_train, y_train)

predictions = model.predict(x_test)
print(f"Accuracy: {accuracy_score(y_test, predictions):.3f}")
print(classification_report(y_test, predictions, target_names=wine.target_names))

# %% [markdown]
# ## Feature importance

# %%
pd.Series(model.feature_importances_, index=x.columns).sort_values(ascending=False).head(8)

# %% [markdown]
# ## Practical note
#
# Decision trees are easy to explain and handle nonlinear splits, but they can overfit quickly. Limiting depth is a simple way to keep the model readable.
